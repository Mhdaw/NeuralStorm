# %%
# !wget "https://www2.census.gov/geo/tiger/GENZ2023/shp/cb_2023_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2022/shp/cb_2022_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2019/shp/cb_2019_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2017/shp/cb_2017_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2016/shp/cb_2016_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2015/shp/cb_2015_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2014/shp/cb_2014_us_county_500k.zip"
# !wget "https://www2.census.gov/geo/tiger/GENZ2013/cb_2013_us_county_500k.zip"
# Out:
# --2025-04-17 14:51:24--  https://www2.census.gov/geo/tiger/GENZ2023/shp/cb_2023_us_county_500k.zip
# Resolving www2.census.gov (www2.census.gov)... 172.65.90.26, 172.65.90.24, 172.65.90.27, ...
# Connecting to www2.census.gov (www2.census.gov)|172.65.90.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘cb_2023_us_county_500k.zip’
#
# cb_2023_us_county_5     [ <=>                ]  11.09M  62.6MB/s    in 0.2s
#
# 2025-04-17 14:51:25 (62.6 MB/s) - ‘cb_2023_us_county_500k.zip’ saved [11630077]
#
# --2025-04-17 14:51:25--  https://www2.census.gov/geo/tiger/GENZ2022/shp/cb_2022_us_county_500k.zip
# Resolving www2.census.gov (www2.census.gov)... 172.65.90.26, 172.65.90.25, 172.65.90.24, ...
# Connecting to www2.census.gov (www2.census.gov)|172.65.90.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11656552 (11M) [application/zip]
# Saving to: ‘cb_2022_us_county_500k.zip’
#
# ...
